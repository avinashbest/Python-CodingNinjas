# %% [markdown]
# ### Recursion

# %% [markdown]
# ##### When a function is calling itself with smaller input which is easier to calculate.

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n-1)

# %%
n = int(input())
factorial(n)
# Out:
# 7
# 5040

# %% [markdown]
# ![Screenshot%20from%202021-01-20%2019-37-25.png](attachment:Screenshot%20from%202021-01-20%2019-37-25.png)
